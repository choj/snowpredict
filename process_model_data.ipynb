# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# setup dataframes

# %%
import os 
os.chdir('new_data')
# !ls
# Out:
# KHNXd20170115t0000.cfradial KHNXd20170127t0400.cfradial
# KHNXd20170115t0200.cfradial KHNXd20170127t0600.cfradial
# KHNXd20170115t0400.cfradial KHNXd20170127t0800.cfradial
# KHNXd20170115t0600.cfradial KHNXd20170127t1000.cfradial
# KHNXd20170115t0800.cfradial KHNXd20170127t1200.cfradial
# KHNXd20170115t1000.cfradial KHNXd20170127t1400.cfradial
# KHNXd20170115t1200.cfradial KHNXd20170127t1600.cfradial
# KHNXd20170115t1400.cfradial KHNXd20170127t1800.cfradial
# KHNXd20170115t1600.cfradial KHNXd20170127t2000.cfradial
# KHNXd20170115t1800.cfradial KHNXd20170127t2200.cfradial
# KHNXd20170115t2000.cfradial KHNXd20170128t0000.cfradial
# KHNXd20170115t2200.cfradial KHNXd20170128t0200.cfradial
# KHNXd20170116t0000.cfradial KHNXd20170128t0400.cfradial
# KHNXd20170116t0200.cfradial KHNXd20170128t0600.cfradial
# KHNXd20170116t0400.cfradial KHNXd20170128t0800.cfradial
# KHNXd20170116t0600.cfradial KHNXd20170128t1000.cfradial
# KHNXd20170116t0800.cfradial KHNXd20170128t1200.cfradial
# KHNXd20170116t1000.cfradial KHNXd20170128t1400.cfradial
# KHNXd20170116t1200.cfradial KHNXd20170128t1600.cfradial
# KHNXd20170116t1400.cfradial KHNXd20170128t1800.cfradial
# KHNXd20170116t1600.cfradial KHNXd20170128t2000.cfradial
# KHNXd20170116t1800.cfradial KHNXd20170128t2200.cfradial
# KHNXd20170116t2000.cfradial KHNXd20170129t0000.cfradial
# KHNXd20170116t2200.cfradial KHNXd20170129t0200.cfradial
# KHNXd20170117t0000.cfradial KHNXd20170129t0400.cfradial
# KHNXd20170117t0200.cfradial KHNXd20170129t0600.cfradial
# KHNXd20170117t0400.cfradial KHNXd20170129t0800.cfradial
# KHNXd20170117t0600.cfradial KHNXd20170129t1000.cfradial
# KHNXd20170117t0800.cfradial KHNXd20170129t1200.cfradial
# KHNXd20170117t1000.cfradial KHNXd20170129t1400.cfradial
# KHNXd20170117t1200.cfradial KHNXd20170129t1600.cfradial
# KHNXd20170117t1400.cfradial KHNXd20170129t1800.cfradial
# KHNXd20170117t1600.cfradial KHNXd20170129t2000.cfradial
# KHNXd20170117t1800.cfradial KHNXd20170129t2200.cfradial
# KHNXd20170117t2000.cfradial KHNXd20170130t0000.cfradial
# KHNXd20170117t2200.cfradial KHNXd20170130t0200.cfradial
# KHNXd20170118t0000.cfradial KHNXd20170130t0400.cfradial
# KHNXd20170118t0200.cfradial KHNXd20170130t0600.cfradial
# KHNXd20170118t0400.cfradial KHNXd20170130t0800.cfradial
# KHNXd20170118t0600.cfradial KHNXd20170130t1000.cfradial
# KHNXd20170118t0800.cfradial KHNXd20170130t1200.cfradial
# KHNXd20170118t1000.cfradial KHNXd20170130t1400.cfradial
# KHNXd20170118t1200.cfradial KHNXd20170130t1600.cfradial
# KHNXd20170118t1400.cfradial KHNXd20170130t1800.cfradial
# KHNXd20170118t1600.cfradial KHNXd20170130t2000.cfradial
# KHNXd20170118t1800.cfradial KHNXd20170130t2200.cfradial
# KHNXd20170118t2000.cfradial KHNXd20170131t0000.cfradial
# KHNXd20170118t2200.cfradial KHNXd20170131t0200.cfradial
# KHNXd20170119t0000.cfradial KHNXd20170131t0400.cfradial
# KHNXd20170119t0200.cfradial KHNXd20170131t0600.cfradial
# KHNXd20170119t0400.cfradial KHNXd20170131t0800.cfradial
# KHNXd20170119t0600.cfradial KHNXd20170131t1000.cfradial
# KHNXd20170119t0800.cfradial KHNXd20170131t1200.cfradial
# KHNXd20170119t1000.cfradial KHNXd20170131t1400.cfradial
# KHNXd20170119t1200.cfradial KHNXd20170131t1600.cfradial
# KHNXd20170119t1400.cfradial KHNXd20170131t1800.cfradial
# KHNXd20170119t1600.cfradial KHNXd20170131t2000.cfradial
# KHNXd20170119t1800.cfradial KHNXd20170131t2200.cfradial
# KHNXd20170119t2000.cfradial KHNXd20170201t0000.cfradial
# KHNXd20170119t2200.cfradial KHNXd20170201t0200.cfradial
# KHNXd20170120t0000.cfradial KHNXd20170201t0400.cfradial
# KHNXd20170120t0200.cfradial KHNXd20170201t0600.cfradial
# KHNXd20170120t0400.cfradial KHNXd20170201t0800.cfradial
# KHNXd20170120t0600.cfradial KHNXd20170201t1000.cfradial
# KHNXd20170120t0800.cfradial KHNXd20170201t1200.cfradial
# KHNXd20170120t1000.cfradial KHNXd20170201t1400.cfradial
# KHNXd20170120t1200.cfradial KHNXd20170201t1600.cfradial
# KHNXd20170120t1400.cfradial KHNXd20170201t1800.cfradial
# KHNXd20170120t1600.cfradial KHNXd20170201t2000.cfradial
# KHNXd20170120t1800.cfradial KHNXd20170201t2200.cfradial
# KHNXd20170120t2000.cfradial KHNXd20170202t0000.cfradial
# KHNXd20170120t2200.cfradial KHNXd20170202t0200.cfradial
# KHNXd20170121t0000.cfradial KHNXd20170202t0400.cfradial
# KHNXd20170121t0200.cfradial KHNXd20170202t0600.cfradial
# KHNXd20170121t0400.cfradial KHNXd20170202t0800.cfradial
# KHNXd20170121t0600.cfradial KHNXd20170202t1000.cfradial
# KHNXd20170121t0800.cfradial KHNXd20170202t1200.cfradial
# KHNXd20170121t1000.cfradial KHNXd20170202t1400.cfradial
# KHNXd20170121t1200.cfradial KHNXd20170202t1600.cfradial
# KHNXd20170121t1400.cfradial KHNXd20170202t1800.cfradial
# KHNXd20170121t1600.cfradial KHNXd20170202t2000.cfradial
# KHNXd20170121t1800.cfradial KHNXd20170202t2200.cfradial
# KHNXd20170121t2000.cfradial KHNXd20170203t0000.cfradial
# KHNXd20170121t2200.cfradial KHNXd20170203t0200.cfradial
# KHNXd20170122t0000.cfradial KHNXd20170203t0400.cfradial
# KHNXd20170122t0200.cfradial KHNXd20170203t0600.cfradial
# KHNXd20170122t0400.cfradial KHNXd20170203t0800.cfradial
# KHNXd20170122t0600.cfradial KHNXd20170203t1000.cfradial
# KHNXd20170122t0800.cfradial KHNXd20170203t1200.cfradial
# KHNXd20170122t1000.cfradial KHNXd20170203t1400.cfradial
# KHNXd20170122t1200.cfradial KHNXd20170203t1600.cfradial
# KHNXd20170122t1400.cfradial KHNXd20170203t1800.cfradial
# KHNXd20170122t1600.cfradial KHNXd20170203t2000.cfradial
# KHNXd20170122t1800.cfradial KHNXd20170203t2200.cfradial
# KHNXd20170122t2000.cfradial KHNXd20170204t0000.cfradial
# KHNXd20170122t2200.cfradial KHNXd20170204t0200.cfradial
# KHNXd20170123t0000.cfradial KHNXd20170204t0400.cfradial
# KHNXd20170123t0200.cfradial KHNXd20170204t0600.cfradial
# KHNXd20170123t0400.cfradial KHNXd20170204t0800.cfradial
# KHNXd20170123t0600.cfradial KHNXd20170204t1000.cfradial
# KHNXd20170123t0800.cfradial KHNXd20170204t1200.cfradial
# KHNXd20170123t1000.cfradial KHNXd20170204t1400.cfradial
# KHNXd20170123t1200.cfradial KHNXd20170204t1600.cfradial
# KHNXd20170123t1400.cfradial KHNXd20170204t1800.cfradial
# KHNXd20170123t1600.cfradial KHNXd20170204t2000.cfradial
# KHNXd20170123t1800.cfradial KHNXd20170204t2200.cfradial
# KHNXd20170123t2000.cfradial KHNXd20170205t0000.cfradial
# KHNXd20170123t2200.cfradial KHNXd20170205t0200.cfradial
# KHNXd20170124t0000.cfradial KHNXd20170205t0400.cfradial
# KHNXd20170124t0200.cfradial KHNXd20170205t0600.cfradial
# KHNXd20170124t0400.cfradial KHNXd20170205t0800.cfradial
# KHNXd20170124t0600.cfradial KHNXd20170205t1000.cfradial
# KHNXd20170124t0800.cfradial KHNXd20170205t1200.cfradial
# KHNXd20170124t1000.cfradial KHNXd20170205t1400.cfradial
# KHNXd20170124t1200.cfradial KHNXd20170205t1600.cfradial
# KHNXd20170124t1400.cfradial KHNXd20170205t1800.cfradial
# KHNXd20170124t1600.cfradial KHNXd20170205t2000.cfradial
# KHNXd20170124t1800.cfradial KHNXd20170205t2200.cfradial
# KHNXd20170124t2000.cfradial KHNXd20170206t0000.cfradial
# KHNXd20170124t2200.cfradial KHNXd20170206t0200.cfradial
# KHNXd20170125t0000.cfradial KHNXd20170206t0400.cfradial
# KHNXd20170125t0200.cfradial KHNXd20170206t0600.cfradial
# KHNXd20170125t0400.cfradial KHNXd20170206t0800.cfradial
# KHNXd20170125t0600.cfradial KHNXd20170206t1000.cfradial
# KHNXd20170125t0800.cfradial KHNXd20170206t1200.cfradial
# KHNXd20170125t1000.cfradial KHNXd20170206t1400.cfradial
# KHNXd20170125t1200.cfradial KHNXd20170206t1600.cfradial
# KHNXd20170125t1400.cfradial KHNXd20170206t1800.cfradial
# KHNXd20170125t1600.cfradial KHNXd20170206t2000.cfradial
# KHNXd20170125t1800.cfradial KHNXd20170206t2200.cfradial
# KHNXd20170125t2000.cfradial KHNXd20170207t0000.cfradial
# KHNXd20170125t2200.cfradial KHNXd20170207t0200.cfradial
# KHNXd20170126t0000.cfradial KHNXd20170207t0400.cfradial
# KHNXd20170126t0200.cfradial KHNXd20170207t0600.cfradial
# KHNXd20170126t0400.cfradial KHNXd20170207t0800.cfradial
# KHNXd20170126t0600.cfradial KHNXd20170207t1000.cfradial
# KHNXd20170126t0800.cfradial KHNXd20170207t1200.cfradial
# KHNXd20170126t1000.cfradial KHNXd20170207t1400.cfradial
# KHNXd20170126t1200.cfradial KHNXd20170207t1600.cfradial
# KHNXd20170126t1400.cfradial KHNXd20170207t1800.cfradial
# KHNXd20170126t1600.cfradial KHNXd20170207t2000.cfradial
# KHNXd20170126t1800.cfradial KHNXd20170207t2200.cfradial
# KHNXd20170126t2000.cfradial backup
# KHNXd20170126t2200.cfradial refl2_df.pkl
# KHNXd20170127t0000.cfradial refl_df.pkl
# KHNXd20170127t0200.cfradial test.pkl

# %%
radar_df = pd.read_pickle('refl_final.pkl')
sr_df = pd.read_pickle('../sr_df.pkl')

# %%
# 41585
radar_df.drop_duplicates(inplace=True)

# %%
# only keep KHNX sensors, and convert everything to metric
srr_df = sr_df[sr_df['r_closest'] == 'khnx'].reset_index()
srr_df.drop('index', axis=1, inplace=True)

srr_df['elev_m'] = srr_df['elev_ft'] * 0.305
srr_df['today_mm'] = srr_df['today_in'] * 25.4
srr_df['r_elev_delta_m'] = srr_df['r_elev_delta_ft'] * 0.305

del srr_df['elev_ft'], srr_df['today_in'], srr_df['r_elev_delta_ft']

srr_grouped = srr_df.groupby('st_code')

# %% [markdown]
# Setup feature columns, drawing from https://www.kaggle.com/c/how-much-did-it-rain-ii/data
# for now, start with
#
# - `Id`
# - `minutes_past` - convert to `hours_past`
# - `radar_dist_km`
# - `Ref` -  Radar reflectivity in dbz
# - `RhoHV` - Correlation coefficient (unitless)
# - `Kdp` - Specific differential phase (deg/km)

# %% [markdown]
# get snow mm deltas for each day pair

# %%
srr_df_backup = srr_df.copy()
all_sensors = []
for g in srr_grouped.groups.keys():
    a_sensor = srr_grouped.get_group(g).copy()
    a_sensor['expected_mm'] = a_sensor['today_mm'].diff()
    #a_sensor['should_be_1day'] = a_sensor['date'].diff()
    all_sensors.append(a_sensor[1:])

sr_df = pd.concat(all_sensors)
del srr_grouped

# %%
# email correspondence with Randall Osterhuber snowlab@att.net. he believes readings are at 8 am
sensor_reading_time = 8.0
sr_df['date'] = sr_df['date'] + pd.Timedelta(str(sensor_reading_time) + 'H')

# %%
# match up radar readings with expected_mm
# compare time, if timedelta is <24 hours then include it
radar_grouped = radar_df.groupby('st_code')
sr_grouped = sr_df.groupby('st_code')

radar_expected = []
for sensor in radar_grouped.groups.keys():
    # we have radar readings at different times, associated with a sensor
    radar_readings = radar_grouped.get_group(sensor)
    
    # we need snow readings for a sensor sensor
    snow_readings = sr_grouped.get_group(sensor)
    
    # select all radar readings with 24H before the snow reading
    for i,row in enumerate(snow_readings.iterrows()):
        snow_reading = row[1]
        time_since_radar  = snow_reading['date'] - radar_readings['time']
        
        # we will be assigning a value, expected_mm, to this, hence the copy
        selected = (time_since_radar < pd.Timedelta('24H')) & (time_since_radar > pd.Timedelta("0H"))
        radar_select = radar_readings.loc[selected].copy()
        radar_select['expected_mm'] = snow_reading['expected_mm']
        # round to 15 minute for grouping
        radar_select['time_until_reading'] = time_since_radar.loc[selected].apply(lambda td: td.round('15MIN'))
        radar_select['time_until_reading_hr'] = \
            radar_select['time_until_reading'].apply(lambda td: round(td.total_seconds()/3600,1))
        radar_select['day_id'] = i
        radar_expected.append(radar_select)

# %% [markdown]
# final cleanup

# %%
radar_expected = pd.concat(radar_expected).reset_index().drop('index', axis=1)
radar_expected['gate_time']= radar_expected['time']
radar_expected['alt_m'] = round(radar_expected['alt_m']/1000)*1000
radar_exp = radar_expected.drop_duplicates()

del radar_exp['time']
del radar_expected

# %% [markdown]
# ### Finalize radar data

# %%
# kill reflectivity values below cutoff. try this later, let NN determine features for now
# noise_cutoff = 12 # dbz
# radar_expected_backup = radar_expected.copy()
# radar_expected[radar_expected['refl'] < noise_cutoff]

# %%
# merge with sr_df to get sensor info like elevation
radar_exp = radar_exp.merge(sr_df[['st_code', 'elev_m', 'r_dist_km', 'r_elev_delta_m']].drop_duplicates(), \
                                    on='st_code')

# %%
rg = radar_exp.groupby(['st_code', 'day_id', 'time_until_reading_hr'])
#rg = radar_expected.groupby(['st_code', 'day_id'])

# %%
len(rg.groups)
# Out:
# 9563

# %% [markdown]
# ### Consolidate altitudes
# each group should become a row

# %%
# %%time
rd_rows = []
for g in rg.groups.keys():
    a_group = rg.get_group(g)
    features = ('refl', 'velocity', 'xcorr_ratio', 'difphase')
    new_row = a_group.iloc[0].drop(['alt_m', 'refl', 'velocity', 'xcorr_ratio', 'difphase'])
    for row in a_group.iterrows():
        row = row[1]
        alt_label = str(int(row['alt_m']))
        for f in features:
            label = f + '_' + alt_label
            new_row[label] = row[f]
    rd_rows.append(new_row)
#     break
# Out:
# CPU times: user 2min 47s, sys: 2.5 s, total: 2min 50s
# Wall time: 2min 54s

# %%
composite_df = pd.DataFrame.from_dict(rd_rows)
composite_df.reset_index(inplace=True, drop=True)

# %%
composite_df[['day_id','time_until_reading_hr','expected_mm']]
# Out:
#       day_id  time_until_reading_hr  expected_mm
# 0         13                    0.0         5.08
# 1         13                    2.0         5.08
# 2         13                    4.0         5.08
# 3         13                    6.0         5.08
# 4         13                    8.0         5.08
# 5         14                    1.8         5.08
# 6         14                    2.0         5.08
# 7         14                    4.0         5.08
# 8         14                    6.0         5.08
# 9         14                    7.8         5.08
# 10        14                    8.0         5.08
# 11        14                   10.0         5.08
# 12        14                   11.8         5.08
# 13        14                   12.0         5.08
# 14        14                   14.0         5.08
# 15        14                   16.0         5.08
# 16        14                   17.8         5.08
# 17        14                   18.0         5.08
# 18        14                   20.0         5.08
# 19        14                   22.0         5.08
# 20        15                    2.0         5.08
# 21        15                    4.0         5.08
# 22        15                    6.0         5.08
# 23        15                    7.8         5.08
# 24        15                    9.8         5.08
# 25        15                   10.0         5.08
# 26        15                   12.0         5.08
# 27        15                   14.0         5.08
# 28        15                   16.0         5.08
# 29        15                   18.0         5.08
# ...      ...                    ...          ...
# 9533      35                   10.0        15.24
# 9534      35                   12.0        15.24
# 9535      35                   14.0        15.24
# 9536      35                   15.8        15.24
# 9537      35                   16.0        15.24
# 9538      35                   18.0        15.24
# 9539      35                   20.0        15.24
# 9540      35                   21.8        15.24
# 9541      35                   22.0        15.24
# 9542      35                   24.0        15.24
# 9543      36                    2.0        43.18
# 9544      36                    4.0        43.18
# 9545      36                    6.0        43.18
# 9546      36                    8.0        43.18
# 9547      36                   10.0        43.18
# 9548      36                   12.0        43.18
# 9549      36                   14.0        43.18
# 9550      36                   16.0        43.18
# 9551      36                   18.0        43.18
# 9552      36                   20.0        43.18
# 9553      36                   22.0        43.18
# 9554      36                   24.0        43.18
# 9555      37                   10.0        76.20
# 9556      37                   12.0        76.20
# 9557      37                   14.0        76.20
# 9558      37                   16.0        76.20
# 9559      37                   18.0        76.20
# 9560      37                   20.0        76.20
# 9561      37                   22.0        76.20
# 9562      37                   24.0        76.20
#
# [9563 rows x 3 columns]

# %%
os.chdir('..')
# !ls
# Out:
# KHNXd20170115t0000-err.txt process_model_data.ipynb
# KHNXd20170115t0200-err.txt process_radar_data.ipynb
# composite_df.pkl           process_sensor_data.ipynb
# data_temp                  rdr_coords.pkl
# get_radar_data.ipynb       ref
# get_snow_data.ipynb        refl_new.pkl
# googleapikey.txt           results_exploration.ipynb
# khnx_radar.png             rf_results.pkl
# kojak-pres.key             rnn_results.pkl
# model.png                  snow_in_chart.png
# model_ens_snow_data.ipynb  snow_scraped_df.pkl
# model_nn_snow_data.ipynb   sr_df.pkl
# new_data

# %%
composite_df.to_pickle('composite_df.pkl')
