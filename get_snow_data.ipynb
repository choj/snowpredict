# %% [markdown]
# First scrape the snow sensor data

# %%
import requests, re
import pickle as pkl
from bs4 import BeautifulSoup
import pandas as pd
import numpy as np

# %%
def get_soup(url):
    response = requests.get(url)
    page = response.text
    if response.status_code != 200:
        print("REQUESTS error")
        print(response.status_code)
    return BeautifulSoup(page, "lxml")

def str2floatflag(s):
    s = s.strip()
    letters = ''
    try:
        num = float(s)
    except ValueError:
        # return tuple contain int and str elements
        if '-' not in s:
            rs = r"[0-9|.]"
            num = "".join(re.findall(rs,s))
            letters = s.strip(num)
        else:
            num = np.NaN
    return (float(num), letters)

# %%
from datetime import timedelta
from datetime import date

start_date, end_date = pd.to_datetime('20170101'), pd.to_datetime('20170302')
sensor_urls = []
sensor_url_root = "https://cdec.water.ca.gov/cgi-progs/snow/PAGE6."
for d in pd.date_range(start_date, end_date):
    sensor_urls.append(sensor_url_root + date.strftime(d, "%Y%m%d"))

# %%
from time import sleep

snow_df = pd.DataFrame()

for url in sensor_urls:
    # get page
    sensor_soup = get_soup(url)

    # get each table row
    data_table = sensor_soup.find_all("table")[0]
    rows = [row for row in data_table.find_all('tr')]

    # get page info
    page_date = pd.to_datetime(sensor_soup.find("h2").next_element)
    print(page_date)

    # get all data for a given day, create a dataframe
    df_rows = [] # list of dicts
    df_row = {}
    for r in rows:
        if r.find_all('font'): # it's a heading
            df_row['area'] = r.find_all('font')[0].text.lower()
        elif r.find_all('td')[0].text.strip() != 'Station': # it's not, and it's not a station heading
            r_data = r.find_all('td')
            df_row['st_name'], df_row['st_code'] = r_data[0].text.strip().lower(), r_data[1].text.strip().lower()
            df_row['agency'] = r_data[2].text.strip().lower()
            df_row['elev_ft'] = int(r_data[3].text.replace(',',''))
            df_row['apr1avg_in'], df_row['apr1avg_in_code'] = str2floatflag(r_data[4].text)
            df_row['today_in'], df_row['today_in_code'] = str2floatflag(r_data[5].text)
            df_row['apr1_pct'], df_row['apr1_pct_code'] = str2floatflag(r_data[6].text.strip('%'))
            df_row['yesday_in'], df_row['yesday_in_code'] = str2floatflag(r_data[7].text)
            df_row['date'], df_row['url'] = page_date, url
            df_rows.append(df_row.copy())
    page_df = pd.DataFrame.from_dict(df_rows)
    snow_df = snow_df.append(page_df)
    print("sleep 1.5 sec")
    sleep(1.5)
# Out:
# 2017-01-01 00:00:00
# sleep 1.5 sec
# 2017-01-02 00:00:00
# sleep 1.5 sec
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-1489c73da100> in <module>()
#      35     snow_df = snow_df.append(page_df)
#      36     print("sleep 1.5 sec")
# ---> 37     sleep(1.5)
#
# KeyboardInterrupt:

# %%
# these are empty for now - should maybe make this conditional
del snow_df['apr1_pct_code']
del snow_df['apr1avg_in_code']

# %%
snow_df.head()
# Out:
#   agency  apr1_pct  apr1avg_in           area       date  elev_ft st_code  \
# 0    dwr      26.0        29.2  trinity river 2017-01-01     7150     pet
# 1    dwr      43.0        39.6  trinity river 2017-01-01     6700     rrm
# 2    dwr       NaN        40.5  trinity river 2017-01-01     6450     bnk
# 3    dwr      27.0        40.3  trinity river 2017-01-01     6400     shm
# 4    dwr      28.0        28.3  trinity river 2017-01-01     6200     mb3
#
#              st_name  today_in today_in_code  \
# 0      peterson flat       7.8             r
# 1  red rock mountain      17.1             r
# 2       bonanza king       NaN
# 3        shimmy lake      11.1             r
# 4   middle boulder 3       8.0             r
#
#                                                  url  yesday_in yesday_in_code
# 0  https://cdec.water.ca.gov/cgi-progs/snow/PAGE6...        7.8              r
# 1  https://cdec.water.ca.gov/cgi-progs/snow/PAGE6...       17.2              r
# 2  https://cdec.water.ca.gov/cgi-progs/snow/PAGE6...        NaN
# 3  https://cdec.water.ca.gov/cgi-progs/snow/PAGE6...       11.3              r
# 4  https://cdec.water.ca.gov/cgi-progs/snow/PAGE6...        7.8              r

# %% [markdown]
# Get lat/long

# %%
soup = get_soup('http://cdec.water.ca.gov/misc/SnowSensors.html')

data_table = soup.find_all("table")[0]
rows = [row for row in data_table.find_all('tr')]

stations_list = []
station = {}
for r in rows:
    row_array = tuple(r.text.split('\n'))
    if len(row_array) == 7:
        station['st_code'] = row_array[0].strip().lower()
        station['st_lat'], station['st_lon'] = float(row_array[3].split()[0]), float(row_array[3].split()[1])
        stations_list.append(station.copy())

# %%
station_coords = pd.DataFrame.from_dict(stations_list)

# %%
snow_coords_df = snow_df.merge(station_coords, on='st_code', how='left')

# %%
snow_coords_df.head(10)
# Out:
#   agency  apr1_pct  apr1avg_in           area       date  elev_ft st_code  \
# 0    dwr      26.0        29.2  trinity river 2017-01-01     7150     pet
# 1    dwr      43.0        39.6  trinity river 2017-01-01     6700     rrm
# 2    dwr       NaN        40.5  trinity river 2017-01-01     6450     bnk
# 3    dwr      27.0        40.3  trinity river 2017-01-01     6400     shm
# 4    dwr      28.0        28.3  trinity river 2017-01-01     6200     mb3
# 5    dwr      29.0        29.9  trinity river 2017-01-01     6030     hig
# 6    dwr      21.0        16.0  trinity river 2017-01-01     5900     sct
# 7    dwr      28.0        22.4  trinity river 2017-01-01     5650     mum
# 8    dwr      37.0        15.8  trinity river 2017-01-01     5100     bfl
# 9   nrcs       NaN         NaN  trinity river 2017-01-01     5100     cwf
#
#              st_name  today_in today_in_code  \
# 0      peterson flat       7.8             r
# 1  red rock mountain      17.1             r
# 2       bonanza king       NaN
# 3        shimmy lake      11.1             r
# 4   middle boulder 3       8.0             r
# 5     highland lakes       8.9             r
# 6     scott mountain       3.5             r
# 7        mumbo basin       6.3             r
# 8           big flat       5.9             r
# 9       crowder flat       0.9             r
#
#                                                  url  yesday_in  \
# 0  https://cdec.water.ca.gov/cgi-progs/snow/PAGE6...        7.8
# 1  https://cdec.water.ca.gov/cgi-progs/snow/PAGE6...       17.2
# 2  https://cdec.water.ca.gov/cgi-progs/snow/PAGE6...        NaN
# 3  https://cdec.water.ca.gov/cgi-progs/snow/PAGE6...       11.3
# 4  https://cdec.water.ca.gov/cgi-progs/snow/PAGE6...        7.8
# 5  https://cdec.water.ca.gov/cgi-progs/snow/PAGE6...        8.8
# 6  https://cdec.water.ca.gov/cgi-progs/snow/PAGE6...        3.4
# 7  https://cdec.water.ca.gov/cgi-progs/snow/PAGE6...        6.0
# 8  https://cdec.water.ca.gov/cgi-progs/snow/PAGE6...        6.0
# 9  https://cdec.water.ca.gov/cgi-progs/snow/PAGE6...        0.9
#
#   yesday_in_code  st_lat   st_lon
# 0              r  41.302 -122.528
# 1              r  41.023 -122.885
# 2                 41.083 -122.628
# 3              r  41.008 -122.800
# 4              r  41.225 -122.811
# 5              r  41.093 -122.483
# 6              r  41.272 -122.718
# 7              r  41.197 -122.523
# 8              r  41.080 -122.942
# 9              r  41.893 -120.752

# %% [markdown]
# Picklin' time

# %%
pkl.dump(snow_coords_df, open( "snow_coords_df.pkl", "wb" ) )
